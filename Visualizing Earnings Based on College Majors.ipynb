# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
recent_grads = pd.read_csv("recent-grads.csv")
#recent_grads.iloc[0]
recent_grads.head(10)
#recent_grads.tail()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %%
#Generate summary statistics for all of numeric columns
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
# Look at the number of rows of recent_grads Data Frame, and Drop rows with missing values. Then count the number of rows of the cleaned data frame 
raw_data_counts = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %%
# Explore if there are correlations between variables using scatter plot graphics
recent_grads.plot(x="Sample_size",y="Median",kind= "scatter")

# %%
recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind= "scatter")

# %%
recent_grads.plot(x="Full_time",y="Median",kind= "scatter")

# %%
recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind= "scatter")

# %%
recent_grads.plot(x="Men",y="Median",kind= "scatter")

# %%
recent_grads.plot(x="Women",y="Median",kind= "scatter")

# %% [markdown]
# ##### Explore relation between students in more popular majors and salary
# In the above graphics is possible to observe that there are no correlation between the salary and students in more popular majors. The Sample_size varible represents a sample of the number of students that are full time employed of each major. The graphic show that when the sample size increase, the median does not follow this increment.
# ##### Explore relation between majored subject with high percentage of woman and salary
# The plot between woman and median depict that there are not correlation between majors with high amount of female and salary. On the contrary while female go up, the median variable remain in the same level or decrement.
# ##### Full time emplyee and median salary
# The plot between these variables doesn´t show any correlation between both variables.There are a cluster of the number of full time employess in the range 0-50000 in which there are any relation between the salary and the full time employees of each major. This cluster show that the median increment is for other causes than the number of full time employment of each major.

# %%
#Explore the distributions of a group of relevant variables with histograms
recent_grads["Sample_size"].hist(bins=15)

# %%
recent_grads["Median"].hist(bins=25)

# %%
recent_grads["Employed"].hist(bins=15)

# %%
recent_grads["Full_time"].hist(bins=15)

# %%
recent_grads["ShareWomen"].hist(bins=15)

# %%
recent_grads["Unemployment_rate"].hist(bins=15)

# %%
recent_grads["Men"].hist(bins=15,range=(0,20000))

# %%
recent_grads["Women"].hist(bins=15, range=(0,20000))

# %% [markdown]
# The histogram of the ShareWoman series, show that around in 70 majors, the level of woman is more than 60% of the total. A preliminary observation of this plot, show that there are a more percentage of woman than males in the majors.
#
# The most common median salary range is between 35000 and 40000 with almost fifty major in this range.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size","Median"]])
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6b23614438>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6b2334eda0>]], dtype=object)

# %% [markdown]
# As we can see in the above scatter matrix, there is no correlation between salary(median variable) and the most popular majors(sample_size variable). That because when the sample_size variable increment, the median does not perform the same movement.
# With the above scatter matrix we can confirm that the most common median salary range is in the range of 35000-40000.

# %%
scatter_matrix(recent_grads[["ShareWomen","Median","Full_time"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6b231a0e10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f6b22fc7d68>]], dtype=object)

# %% [markdown]
# From the scatter matrix above, we can visualize the correlation and distribution of ShareWomen, Median, and Full_time.
#
# ##### ShareWoman vs Median Salary
# A feature that we can visuzalize is that there is a negative correlation between the percentage of woman in majors and the median salary. When the variable ShareWoman(woman as share of total in each major) go down the median salary has an increment. This correlation is not strong but is a visible correlation.
#
# ##### Full time employee vs median salary
# Is not possible to conclude that there is a correlation between the number of full-time employee in each mayor and the median salary. The matrix show that when the number of full time employee in each major go up, the median salary don´t show any increment.

# %%
# In this step, I use the bar plot of pandas to analyze the percentage of women in the 10 highest paying majors and the 10 lowest paying majors
recent_grads[:10]["ShareWomen"].plot(kind="bar")

# %%
recent_grads[163:173]["ShareWomen"].plot(kind="bar")

# %% [markdown]
# From the bar plots above, we can conclude that while the majors have the best ranking in the median salary variable, the percentage of woman in these majors is low. Only in the major in the 7 position the ShareWomen variable is high than 0.5.
# In relation of the lower majors in the median salary ranking, the percentage of women in these majors is very superior than men.

# %%
recent_grads[:10]["Unemployment_rate"].plot(kind="bar")

# %%
recent_grads[163:173]["Unemployment_rate"].plot(kind="bar")

# %% [markdown]
# Respect the unemployment rate across the highest and lowest paying majors, there is not a sensible difference in the unemployment rate observed in the highest paying majors respect the lowest paying majors.
# In the highest paying majors there are 3 majors that don´t overcome the 5%, while in the lowest paying majors there are 2 that don´t overcome the 5% unemployemnt rate.
#
# While is possible to observe that in the highest paying major the unemployment rate is less, the difference is not so significtative.

# %%
# Compare the number of men with the number of women in each category of majors
recent_grads[:4][["Men","Women"]].plot.bar(stacked=True)
recent_grads[4:5][["Men","Women"]].plot.bar(stacked=True)
recent_grads[5:8][["Men","Women"]].plot.bar(stacked=True)

# %% [markdown]
# I construct bar plots to observe the distribution between men and women in the highest ranking majors. As the plots shows, in the highest ranking majors there is a highly predominance of men with more than 90% of men in the first 4 majors, more than 50% in the 5th, 6 and 7th majors and only in the 8th major there is a superiority of women.
#
# In the next bar plot, I will analyze the presence of each category of men and women in the lowest major ranking.

# %%
recent_grads[163:173][["Men","Women"]].plot.bar(stacked=True)

# %% [markdown]
# The grouped bar plot show that in the lowest ranking majors, the presence of woman is highly superior respect of men. We can conclude that there is a tendency that woman receive lower salaries in relation of men.

# %%
# Analyze the distribution of median salaries and unemployment rate
fig,ax = plt.subplots()
ax.boxplot(recent_grads["Median"])
ax.set_ylim(0,80000)
ax.set_xticklabels(["Salary"])

# %% [markdown]
# In the median boxplot, is possible to observe that the first quartile of the distribution(0-25%) is within the range 21000-31000, while the 2nd quartile is the shortest with a bounded interval between 32000-35000.
# The third quartil goes between 35000 to 45000 and the last queartile is the largest with an interval of 45000-60000.

# %%
#Analyze the distribution of the unemployment rate variable
fig,ax = plt.subplots()
ax.boxplot(recent_grads["Unemployment_rate"])
#ax.set_ylim(0,80000)
ax.set_xticklabels(["Unemployment rate"])

# %% [markdown]
# The boxplot of the unemployment rate show that the median of the median of the unemployment rate is around 7% and the range of the variable are between 0 to 13%.
